# %% [markdown]
# import subprocess
#
# # Run the compiled C++ program
# subprocess.run(
#     ["./build/cosim-fullorder", "-d", "10"],
#     capture_output=True,
#     text=True
# )

# %%
import matplotlib.pyplot as plt

# %%
import ipympl
print("ipympl is installed.")
# Out:
# ipympl is installed.

# %%
import pandas as pd

# Replace 'path/to/your/file.csv' with the actual file path
# df1 = pd.read_csv('./logs/-d_EMT/-d_EMT.csv',skipinitialspace=True)


# df1 = pd.read_csv('build/logs/Cosim-IEEE9_EMT/Cosim-IEEE9_EMT.csv',skipinitialspace=True)


# # Replace 'path/to/your/file.csv' with the actual file path
#df1 = pd.read_csv('./logs/Cosim-IEEE9_EMT/Cosim-IEEE9_EMT.csv',skipinitialspace=True)
df1 = pd.read_csv('/logs/Cosim-IEEE9-4order-no-loadstep_EMT/Cosim-IEEE9-4order-no-loadstep_EMT.csv', 
                  usecols=['time', 'v6_0', 'v6_1', 'v6_2','GEN1.V_0','GEN1.V_1','GEN1.V_2','GEN2.V_0','GEN2.V_1','GEN2.V_2','GEN3.V_0','GEN3.V_1','GEN3.V_2',
                          'GEN1.I_0','GEN1.I_1','GEN1.I_2','GEN2.I_0','GEN2.I_1','GEN2.I_2','GEN3.I_0','GEN3.I_1','GEN3.I_2','GEN1.omega','GEN2.omega','GEN3.omega'], 
                  skipinitialspace=True)[::20]
print(df1.head())
# Out:
#      time     GEN1.I_0     GEN1.I_1     GEN1.I_2      GEN1.V_0      GEN1.V_1  \
# 0   0.000     0.000000 -2976.038641  2976.038641  14011.081329  -7005.540664
# 20  0.001  7512.630434 -5044.655169 -2467.975265  13542.779516  -3709.684899
# 40  0.002  8377.721663 -2403.470554 -5974.251109  11475.714560   1237.905276
# 60  0.003  3939.922539  3380.969033 -7320.891572   7877.900198   6657.383423
# 80  0.004  1995.900576  5212.059992 -7207.960568   2818.554457  10867.341610
#
#         GEN1.V_2  GEN1.omega     GEN2.I_0     GEN2.I_1  ...     GEN3.I_0  \
# 0   -7005.540664    1.000000     0.000000 -1571.348403  ...     0.000000
# 20  -9833.094617    0.999989  5940.223739 -3233.196200  ...  6936.296953
# 40 -12713.619837    0.999952  5155.063544  -958.910410  ...  6356.818252
# 60 -14535.283620    0.999915  2636.380734  2576.382324  ...  3250.103654
# 80 -13685.896067    0.999877  1144.826990  3128.375884  ...  2002.401606
#
#        GEN3.I_1     GEN3.I_2      GEN3.V_0     GEN3.V_1      GEN3.V_2  \
# 0  -2185.990692  2185.990692  11549.344137 -5774.672069  -5774.672069
# 20 -2915.873914 -4020.423039  12094.013293 -4871.210670  -7222.802623
# 40 -1346.965753 -5009.852500  10349.740525  -233.295169 -10116.445356
# 60  1364.623082 -4614.726735   7058.899152  4996.219528 -12055.118680
# 80  2399.783229 -4402.184835   2730.410689  8739.625444 -11470.036133
#
#     GEN3.omega           v6_0           v6_1           v6_2
# 0     1.000000  187794.213613  -93897.106807  -93897.106807
# 20    0.999933  122921.801907  -44007.448123  -78914.353784
# 40    0.999715  201060.115658  -39846.664149 -161213.451509
# 60    0.999538  141391.649256   54304.915736 -195696.564993
# 80    0.999395   56648.644421  137729.923562 -194378.567983
#
# [5 rows x 25 columns]

# %%
import pandas as pd
df2 = pd.read_csv('/logs/Cosim-IEEE9-4order-33-percent-loadstep_EMT/Cosim-IEEE9-4order-33-percent-loadstep_EMT.csv', 
                  usecols=['time', 'v6_0', 'v6_1', 'v6_2','GEN1.V_0','GEN1.V_1','GEN1.V_2','GEN2.V_0','GEN2.V_1','GEN2.V_2','GEN3.V_0','GEN3.V_1','GEN3.V_2',
                          'GEN1.I_0','GEN1.I_1','GEN1.I_2','GEN2.I_0','GEN2.I_1','GEN2.I_2','GEN3.I_0','GEN3.I_1','GEN3.I_2','GEN1.omega','GEN2.omega','GEN3.omega'], 
                  skipinitialspace=True)[::20]
print(df2.head())
# Out:
#      time     GEN1.I_0     GEN1.I_1     GEN1.I_2      GEN1.V_0      GEN1.V_1  \
# 0   0.000     0.000000 -2976.038641  2976.038641  14011.081329  -7005.540664
# 20  0.001  7512.630434 -5044.655169 -2467.975265  13542.779516  -3709.684899
# 40  0.002  8377.721663 -2403.470554 -5974.251109  11475.714560   1237.905276
# 60  0.003  3939.922539  3380.969033 -7320.891572   7877.900198   6657.383423
# 80  0.004  1995.900576  5212.059992 -7207.960568   2818.554457  10867.341610
#
#         GEN1.V_2  GEN1.omega     GEN2.I_0     GEN2.I_1  ...     GEN3.I_0  \
# 0   -7005.540664    1.000000     0.000000 -1571.348403  ...     0.000000
# 20  -9833.094617    0.999989  5940.223739 -3233.196200  ...  6936.296953
# 40 -12713.619837    0.999952  5155.063544  -958.910410  ...  6356.818252
# 60 -14535.283620    0.999915  2636.380734  2576.382324  ...  3250.103654
# 80 -13685.896067    0.999877  1144.826990  3128.375884  ...  2002.401606
#
#        GEN3.I_1     GEN3.I_2      GEN3.V_0     GEN3.V_1      GEN3.V_2  \
# 0  -2185.990692  2185.990692  11549.344137 -5774.672069  -5774.672069
# 20 -2915.873914 -4020.423039  12094.013293 -4871.210670  -7222.802623
# 40 -1346.965753 -5009.852500  10349.740525  -233.295169 -10116.445356
# 60  1364.623082 -4614.726735   7058.899152  4996.219528 -12055.118680
# 80  2399.783229 -4402.184835   2730.410689  8739.625444 -11470.036133
#
#     GEN3.omega           v6_0           v6_1           v6_2
# 0     1.000000  187794.213613  -93897.106807  -93897.106807
# 20    0.999933  122921.801907  -44007.448123  -78914.353784
# 40    0.999715  201060.115658  -39846.664149 -161213.451509
# 60    0.999538  141391.649256   54304.915736 -195696.564993
# 80    0.999395   56648.644421  137729.923562 -194378.567983
#
# [5 rows x 25 columns]

# %%
import pandas as pd
df3 = pd.read_csv('/logs/Cosim-IEEE9-4order-66-percent-loadstep_EMT/Cosim-IEEE9-4order-66-percent-loadstep_EMT.csv', 
                  usecols=['time', 'v6_0', 'v6_1', 'v6_2','GEN1.V_0','GEN1.V_1','GEN1.V_2','GEN2.V_0','GEN2.V_1','GEN2.V_2','GEN3.V_0','GEN3.V_1','GEN3.V_2',
                          'GEN1.I_0','GEN1.I_1','GEN1.I_2','GEN2.I_0','GEN2.I_1','GEN2.I_2','GEN3.I_0','GEN3.I_1','GEN3.I_2','GEN1.omega','GEN2.omega','GEN3.omega'], 
                  skipinitialspace=True)[::20]
print(df3.head())
# Out:
#      time     GEN1.I_0     GEN1.I_1     GEN1.I_2      GEN1.V_0      GEN1.V_1  \
# 0   0.000     0.000000 -2976.038641  2976.038641  14011.081329  -7005.540664
# 20  0.001  7512.630434 -5044.655169 -2467.975265  13542.779516  -3709.684899
# 40  0.002  8377.721663 -2403.470554 -5974.251109  11475.714560   1237.905276
# 60  0.003  3939.922539  3380.969033 -7320.891572   7877.900198   6657.383423
# 80  0.004  1995.900576  5212.059992 -7207.960568   2818.554457  10867.341610
#
#         GEN1.V_2  GEN1.omega     GEN2.I_0     GEN2.I_1  ...     GEN3.I_0  \
# 0   -7005.540664    1.000000     0.000000 -1571.348403  ...     0.000000
# 20  -9833.094617    0.999989  5940.223739 -3233.196200  ...  6936.296953
# 40 -12713.619837    0.999952  5155.063544  -958.910410  ...  6356.818252
# 60 -14535.283620    0.999915  2636.380734  2576.382324  ...  3250.103654
# 80 -13685.896067    0.999877  1144.826990  3128.375884  ...  2002.401606
#
#        GEN3.I_1     GEN3.I_2      GEN3.V_0     GEN3.V_1      GEN3.V_2  \
# 0  -2185.990692  2185.990692  11549.344137 -5774.672069  -5774.672069
# 20 -2915.873914 -4020.423039  12094.013293 -4871.210670  -7222.802623
# 40 -1346.965753 -5009.852500  10349.740525  -233.295169 -10116.445356
# 60  1364.623082 -4614.726735   7058.899152  4996.219528 -12055.118680
# 80  2399.783229 -4402.184835   2730.410689  8739.625444 -11470.036133
#
#     GEN3.omega           v6_0           v6_1           v6_2
# 0     1.000000  187794.213613  -93897.106807  -93897.106807
# 20    0.999933  122921.801907  -44007.448123  -78914.353784
# 40    0.999715  201060.115658  -39846.664149 -161213.451509
# 60    0.999538  141391.649256   54304.915736 -195696.564993
# 80    0.999395   56648.644421  137729.923562 -194378.567983
#
# [5 rows x 25 columns]

# %%
import pandas as pd
df4 = pd.read_csv('/logs/Cosim-IEEE9-4order-133-percent-loadstep_EMT/Cosim-IEEE9-4order-133-percent-loadstep_EMT.csv', 
                  usecols=['time', 'v6_0', 'v6_1', 'v6_2','GEN1.V_0','GEN1.V_1','GEN1.V_2','GEN2.V_0','GEN2.V_1','GEN2.V_2','GEN3.V_0','GEN3.V_1','GEN3.V_2',
                          'GEN1.I_0','GEN1.I_1','GEN1.I_2','GEN2.I_0','GEN2.I_1','GEN2.I_2','GEN3.I_0','GEN3.I_1','GEN3.I_2','GEN1.omega','GEN2.omega','GEN3.omega'], 
                  skipinitialspace=True)[::20]
print(df4.head())
# Out:
#      time     GEN1.I_0     GEN1.I_1     GEN1.I_2      GEN1.V_0      GEN1.V_1  \
# 0   0.000     0.000000 -2976.038641  2976.038641  14011.081329  -7005.540664
# 20  0.001  7512.630434 -5044.655169 -2467.975265  13542.779516  -3709.684899
# 40  0.002  8377.721663 -2403.470554 -5974.251109  11475.714560   1237.905276
# 60  0.003  3939.922539  3380.969033 -7320.891572   7877.900198   6657.383423
# 80  0.004  1995.900576  5212.059992 -7207.960568   2818.554457  10867.341610
#
#         GEN1.V_2  GEN1.omega     GEN2.I_0     GEN2.I_1  ...     GEN3.I_0  \
# 0   -7005.540664    1.000000     0.000000 -1571.348403  ...     0.000000
# 20  -9833.094617    0.999989  5940.223739 -3233.196200  ...  6936.296953
# 40 -12713.619837    0.999952  5155.063544  -958.910410  ...  6356.818252
# 60 -14535.283620    0.999915  2636.380734  2576.382324  ...  3250.103654
# 80 -13685.896067    0.999877  1144.826990  3128.375884  ...  2002.401606
#
#        GEN3.I_1     GEN3.I_2      GEN3.V_0     GEN3.V_1      GEN3.V_2  \
# 0  -2185.990692  2185.990692  11549.344137 -5774.672069  -5774.672069
# 20 -2915.873914 -4020.423039  12094.013293 -4871.210670  -7222.802623
# 40 -1346.965753 -5009.852500  10349.740525  -233.295169 -10116.445356
# 60  1364.623082 -4614.726735   7058.899152  4996.219528 -12055.118680
# 80  2399.783229 -4402.184835   2730.410689  8739.625444 -11470.036133
#
#     GEN3.omega           v6_0           v6_1           v6_2
# 0     1.000000  187794.213613  -93897.106807  -93897.106807
# 20    0.999933  122921.801907  -44007.448123  -78914.353784
# 40    0.999715  201060.115658  -39846.664149 -161213.451509
# 60    0.999538  141391.649256   54304.915736 -195696.564993
# 80    0.999395   56648.644421  137729.923562 -194378.567983
#
# [5 rows x 25 columns]

# %%
import pandas as pd
df5 = pd.read_csv('/logs/Cosim-IEEE9-4order-166-percent-loadstep_EMT/Cosim-IEEE9-4order-166-percent-loadstep_EMT.csv', 
                  usecols=['time', 'v6_0', 'v6_1', 'v6_2','GEN1.V_0','GEN1.V_1','GEN1.V_2','GEN2.V_0','GEN2.V_1','GEN2.V_2','GEN3.V_0','GEN3.V_1','GEN3.V_2',
                          'GEN1.I_0','GEN1.I_1','GEN1.I_2','GEN2.I_0','GEN2.I_1','GEN2.I_2','GEN3.I_0','GEN3.I_1','GEN3.I_2','GEN1.omega','GEN2.omega','GEN3.omega'], 
                  skipinitialspace=True)[::20]
print(df5.head())
# Out:
#      time     GEN1.I_0     GEN1.I_1     GEN1.I_2      GEN1.V_0      GEN1.V_1  \
# 0   0.000     0.000000 -2976.038641  2976.038641  14011.081329  -7005.540664
# 20  0.001  7512.630434 -5044.655169 -2467.975265  13542.779516  -3709.684899
# 40  0.002  8377.721663 -2403.470554 -5974.251109  11475.714560   1237.905276
# 60  0.003  3939.922539  3380.969033 -7320.891572   7877.900198   6657.383423
# 80  0.004  1995.900576  5212.059992 -7207.960568   2818.554457  10867.341610
#
#         GEN1.V_2  GEN1.omega     GEN2.I_0     GEN2.I_1  ...     GEN3.I_0  \
# 0   -7005.540664    1.000000     0.000000 -1571.348403  ...     0.000000
# 20  -9833.094617    0.999989  5940.223739 -3233.196200  ...  6936.296953
# 40 -12713.619837    0.999952  5155.063544  -958.910410  ...  6356.818252
# 60 -14535.283620    0.999915  2636.380734  2576.382324  ...  3250.103654
# 80 -13685.896067    0.999877  1144.826990  3128.375884  ...  2002.401606
#
#        GEN3.I_1     GEN3.I_2      GEN3.V_0     GEN3.V_1      GEN3.V_2  \
# 0  -2185.990692  2185.990692  11549.344137 -5774.672069  -5774.672069
# 20 -2915.873914 -4020.423039  12094.013293 -4871.210670  -7222.802623
# 40 -1346.965753 -5009.852500  10349.740525  -233.295169 -10116.445356
# 60  1364.623082 -4614.726735   7058.899152  4996.219528 -12055.118680
# 80  2399.783229 -4402.184835   2730.410689  8739.625444 -11470.036133
#
#     GEN3.omega           v6_0           v6_1           v6_2
# 0     1.000000  187794.213613  -93897.106807  -93897.106807
# 20    0.999933  122921.801907  -44007.448123  -78914.353784
# 40    0.999715  201060.115658  -39846.664149 -161213.451509
# 60    0.999538  141391.649256   54304.915736 -195696.564993
# 80    0.999395   56648.644421  137729.923562 -194378.567983
#
# [5 rows x 25 columns]

# %%
print(df1.keys())
# Out:
# Index(['time', 'GEN1.I_0', 'GEN1.I_1', 'GEN1.I_2', 'GEN1.V_0', 'GEN1.V_1',
#        'GEN1.V_2', 'GEN1.omega', 'GEN2.I_0', 'GEN2.I_1', 'GEN2.I_2',
#        'GEN2.V_0', 'GEN2.V_1', 'GEN2.V_2', 'GEN2.omega', 'GEN3.I_0',
#        'GEN3.I_1', 'GEN3.I_2', 'GEN3.V_0', 'GEN3.V_1', 'GEN3.V_2',
#        'GEN3.omega', 'v6_0', 'v6_1', 'v6_2'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib widget

### NO LOADSTEP ###

gen_vars = {
    'i_gen1': ['GEN1.I_0', 'GEN1.I_1', 'GEN1.I_2'],
    'i_gen2': ['GEN2.I_0', 'GEN2.I_1', 'GEN2.I_2'],
    'i_gen3': ['GEN3.I_0', 'GEN3.I_1', 'GEN3.I_2'],
}


dataframes = [df1, df2, df3, df4, df5]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('Current')
    ax.grid(True)
    ax.legend(title="Phase")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt

dataframes = [df1, df2, df3, df4, df5]
phases = ['v6_0', 'v6_1', 'v6_2']
num_runs = len(dataframes)

fig, axes = plt.subplots(nrows=num_runs, ncols=len(phases), 
                         figsize=(15, 3*num_runs), sharex=True)

for i, df in enumerate(dataframes):
    for j, phase in enumerate(phases):
        ax = axes[i, j]
        ax.plot(df['time'], df[phases])
        ax.set_title(f'Run {i+1} – {phases}')
        ax.set_ylabel('Voltage [V]')
        if i == num_runs - 1:
            ax.set_xlabel('Time [s]')

plt.tight_layout()
plt.show()

### RUN 1 - no loadstep, RUN 2 - 33% Load, RUN 3 - 66% Load, RUN 4 - 133% Load, RUN 5 - 166% Load ###
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt


dfs = [df1, df2, df3, df4, df5]
generators = {
    'GEN1': ['GEN1.I_0', 'GEN1.I_1', 'GEN1.I_2'],
    'GEN2': ['GEN2.I_0', 'GEN2.I_1', 'GEN2.I_2'],
    'GEN3': ['GEN3.I_0', 'GEN3.I_1', 'GEN3.I_2'],
}

num_runs = len(dfs)
num_gens = len(generators)

fig, axes = plt.subplots(nrows=num_runs, ncols=num_gens, 
                         figsize=(5*num_gens, 3*num_runs), sharex=True)

for i, df in enumerate(dfs):
    for j, (gen_name, cols) in enumerate(generators.items()):
        ax = axes[i, j]
        for col in cols:
            ax.plot(df['time'], df[col], label=col.split('.')[-1])
        ax.set_title(f'Run {i+1} – {gen_name}')
        ax.set_ylabel('Current [A]')
        if i == num_runs - 1:
            ax.set_xlabel('Time [s]')
        if i == 0:
            ax.legend()

plt.tight_layout()
plt.show()


### RUN 1 - no loadstep, RUN 2 - 33% Load, RUN 3 - 66% Load, RUN 4 - 133% Load, RUN 5 - 166% Load ###
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt


dfs = [df1, df2, df3, df4, df5]
generators = {
    'GEN1': ['GEN1.V_0', 'GEN1.V_1', 'GEN1.V_2'],
    'GEN2': ['GEN2.V_0', 'GEN2.V_1', 'GEN2.V_2'],
    'GEN3': ['GEN3.V_0', 'GEN3.V_1', 'GEN3.V_2'],
}

num_runs = len(dfs)
num_gens = len(generators)

fig, axes = plt.subplots(nrows=num_runs, ncols=num_gens, 
                         figsize=(5*num_gens, 3*num_runs), sharex=True)

for i, df in enumerate(dfs):
    for j, (gen_name, cols) in enumerate(generators.items()):
        ax = axes[i, j]
        for col in cols:
            ax.plot(df['time'], df[col], label=col.split('.')[-1])
        ax.set_title(f'Run {i+1} – {gen_name}')
        ax.set_ylabel('Voltage [V]')
        if i == num_runs - 1:
            ax.set_xlabel('Time [s]')
        if i == 0:
            ax.legend()

plt.tight_layout()
plt.show()


### RUN 1 - no loadstep, RUN 2 - 33% Load, RUN 3 - 66% Load, RUN 4 - 133% Load, RUN 5 - 166% Load ###
# Out:
# /usr/local/lib/python3.13/site-packages/ipympl/backend_nbagg.py:335: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   self.figure.savefig(buf, format='png', dpi='figure')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import matplotlib.pyplot as plt

dfs = [df1, df2, df3, df4, df5]
omega_cols = ['GEN1.omega', 'GEN2.omega', 'GEN3.omega']
num_runs = len(dfs)
num_gens = len(omega_cols)

fig, axes = plt.subplots(nrows=num_runs, ncols=num_gens, 
                         figsize=(5*num_gens, 3*num_runs), sharex=True)

for i, df in enumerate(dfs):
    for j, col in enumerate(omega_cols):
        ax = axes[i, j]
        ax.plot(df['time'], df[col])
        ax.set_title(f'Run {i+1} – {col.split(".")[0]}')
        ax.set_ylabel('ω [rad/s]')
        if i == num_runs - 1:
            ax.set_xlabel('Time [s]')

plt.tight_layout()
plt.show()

### RUN 1 - no loadstep, RUN 2 - 33% Load, RUN 3 - 66% Load, RUN 4 - 133% Load, RUN 5 - 166% Load ###
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
gen_vars = {
    'v_gen1': ['GEN1.V_0', 'GEN1.V_1', 'GEN1.V_2'],
    'v_gen2': ['GEN2.V_0', 'GEN2.V_1', 'GEN2.V_2'],
    'v_gen3': ['GEN3.V_0', 'GEN3.V_1', 'GEN3.V_2'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('Voltage')
    ax.grid(True)
    ax.legend(title="Phase")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
gen_vars = {
    'omega_gen1': ['GEN1.omega'],
    'omega_gen2': ['GEN2.omega'],
    'omega_gen3': ['GEN3.omega'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('omega')
    ax.grid(True)
    ax.legend(title="Phase")
    ax.set_ylim([0.8, 1.1])

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
gen_vars = {
    'delta_gen1': ['GEN1.delta'],
    'delta_gen2': ['GEN2.delta'],
    'delta_gen3': ['GEN3.delta'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('delta')
    ax.grid(True)
    ax.legend(title="Phase")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
gen_vars = {
    'v_6': ['v6_0','v6_1','v6_2'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(2, 1, figsize=(12, 9))  # 3 rows, 1 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('Voltage')
    ax.grid(True)
    ax.legend(title="Voltage")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
