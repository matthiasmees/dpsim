# %% [markdown]
# import subprocess
#
# # Run the compiled C++ program
# subprocess.run(
#     ["./build/cosim-fullorder", "-d", "10"],
#     capture_output=True,
#     text=True
# )

# %%
import matplotlib.pyplot as plt

# %%
import ipympl
print("ipympl is installed.")
# Out:
# ipympl is installed.

# %%
import pandas as pd

# Replace 'path/to/your/file.csv' with the actual file path
# df1 = pd.read_csv('./logs/-d_EMT/-d_EMT.csv',skipinitialspace=True)


# df1 = pd.read_csv('build/logs/Cosim-IEEE9_EMT/Cosim-IEEE9_EMT.csv',skipinitialspace=True)


# # Replace 'path/to/your/file.csv' with the actual file path
#df1 = pd.read_csv('./logs/Cosim-IEEE9_EMT/Cosim-IEEE9_EMT.csv',skipinitialspace=True)
df1 = pd.read_csv('/logs/Cosim-IEEE9-4order_EMT/Cosim-IEEE9-4order_EMT.csv', skipinitialspace=True)
#df1 = pd.read_csv('./build/logs/EMT_WSCC-9bus_VBR/EMT_WSCC-9bus_VBR.csv',skipinitialspace=True)



print(df1.head())
# Out:
#       time    GEN1.I_0     GEN1.I_1     GEN1.I_2      GEN1.V_0     GEN1.V_1  \
# 0  0.00000    0.000000 -2976.038641  2976.038641  14011.081329 -7005.540664
# 1  0.00005   70.124880 -2974.995032  2904.870152  14015.403755 -6780.284632
# 2  0.00010  136.965891 -2876.396862  2739.430971  14032.910960 -6561.439401
# 3  0.00015  211.224277 -2661.747916  2450.523639  14068.279696 -6354.528804
# 4  0.00020  302.944877 -2358.041752  2055.096875  14117.548049 -6160.431843
#
#       GEN1.V_2  GEN1.delta  GEN1.omega    GEN2.I_0  ...          v6_2  \
# 0 -7005.540664         0.0         1.0    0.000000  ... -93897.106807
# 1 -7235.119123         0.0         1.0   39.256012  ... -94072.986021
# 2 -7471.471560        -0.0         1.0   76.072897  ... -91352.592266
# 3 -7713.750892        -0.0         1.0  119.874557  ... -88554.811122
# 4 -7957.116207        -0.0         1.0  178.384973  ... -85573.266230
#
#             v7_0           v7_1          v7_2           v8_0          v8_1  \
# 0  187794.213613  -93897.106807 -93897.106807  187794.213613 -93897.106807
# 1  187769.889240  -94986.640181 -92783.249059  178427.976585 -84966.036118
# 2  187508.376184  -99857.438621 -87650.937562  160980.581236 -71310.983705
# 3  186593.917049 -103628.092630 -82965.824418  146328.295576 -60198.787915
# 4  184641.956442 -105677.509979 -78964.446463  134815.130376 -52033.496471
#
#            v8_2           v9_0           v9_1          v9_2
# 0 -93897.106807  187794.213613  -93897.106807 -93897.106807
# 1 -93461.940466  187795.531407  -94637.262336 -93158.269072
# 2 -89669.597531  187697.568039  -98963.595484 -88733.972555
# 3 -86129.507661  187270.817544 -102632.164932 -84638.652612
# 4 -82781.633904  186296.262470 -105248.691449 -81047.571021
#
# [5 rows x 107 columns]

# %%
print(df1.keys())
# Out:
# Index(['time', 'GEN1.I_0', 'GEN1.I_1', 'GEN1.I_2', 'GEN1.V_0', 'GEN1.V_1',
#        'GEN1.V_2', 'GEN1.delta', 'GEN1.omega', 'GEN2.I_0',
#        ...
#        'v6_2', 'v7_0', 'v7_1', 'v7_2', 'v8_0', 'v8_1', 'v8_2', 'v9_0', 'v9_1',
#        'v9_2'],
#       dtype='object', length=107)

# %%
# %matplotlib widget
gen_vars = {
    'i_gen1': ['GEN1.I_0', 'GEN1.I_1', 'GEN1.I_2'],
    'i_gen2': ['GEN2.I_0', 'GEN2.I_1', 'GEN2.I_2'],
    'i_gen3': ['GEN3.I_0', 'GEN3.I_1', 'GEN3.I_2'],
}




dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('Current')
    ax.grid(True)
    ax.legend(title="Phase")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
gen_vars = {
    'v_gen1': ['GEN1.V_0', 'GEN1.V_1', 'GEN1.V_2'],
    'v_gen2': ['GEN2.V_0', 'GEN2.V_1', 'GEN2.V_2'],
    'v_gen3': ['GEN3.V_0', 'GEN3.V_1', 'GEN3.V_2'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('Voltage')
    ax.grid(True)
    ax.legend(title="Phase")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
gen_vars = {
    'omega_gen1': ['GEN1.omega'],
    'omega_gen2': ['GEN2.omega'],
    'omega_gen3': ['GEN3.omega'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('omega')
    ax.grid(True)
    ax.legend(title="Phase")
    ax.set_ylim([0.9, 1.1])

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
gen_vars = {
    'delta_gen1': ['GEN1.delta'],
    'delta_gen2': ['GEN2.delta'],
    'delta_gen3': ['GEN3.delta'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(1, 3, figsize=(12, 3))  # 1 row, 3 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('delta')
    ax.grid(True)
    ax.legend(title="Phase")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
gen_vars = {
    'v_6': ['v6_0','v6_1','v6_2'],
}

dataframes = [df1]
titles = ['Sim']

fig, axes = plt.subplots(2, 1, figsize=(12, 9))  # 3 rows, 1 columns

df = dataframes[0]  # Since you only have one dataframe

for ax, (gen_name, var_list) in zip(axes, gen_vars.items()):
    for var in var_list:
        ax.plot(df['time'].values, df[var].values, linestyle="--", label=var.split('_')[-1])
    ax.set_title(gen_name)
    ax.set_xlabel('Time')
    ax.set_ylabel('Voltage')
    ax.grid(True)
    ax.legend(title="Voltage")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_69588/3601029522.py:22: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
